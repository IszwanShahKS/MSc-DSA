# %%
# import packages

from rich import print

# %% [markdown]
# # Import Module

# %%
from Property_Class import Landed
# Out:
# Each unit of 'double storey house' with a size of 2,480 sq ft has 6 rooms and 4 bathrooms.
# It is located in Setia Alamsari, Kajang with a selling price starting from RM 650,000.
# Original Size & Price of The Property:
# Each unit of 'bungalow' with a size of 5,600 sq ft has 7 rooms and 5 bathrooms.
# It is located in Presint 12, Putrajaya with a selling price starting from RM 1,250,000.
# The Updated Size & Price of The Property:
# Each unit of 'bungalow' with a size of 5,700 sq ft has 7 rooms and 5 bathrooms.
# It is located in Presint 12, Putrajaya with a selling price starting from RM 1,300,000.
# Original Number of Rooms & Price of The Property:
# Each unit of 'condominium' with a size of 1,150 sq ft has 3 rooms and 2 bathrooms.
# It is located in Gamuda Cove, Sepang with a selling price starting from RM 375,000.
# The Updated Number of Rooms  & Price of The Property:
# Each unit of 'condominium' with a size of 1,150 sq ft has 4 rooms and 2 bathrooms.
# ...

# %%
new_property = Landed("superlink double storey house", 2200, 5, 3, "Rimbayu", 700000)
new_property.describe_property()
new_property.extra_land(175)
# Out:
# Each unit of superlink double storey house with a size of 2,200 sq ft has 5 rooms and 3 bathrooms.
# It is located in Rimbayu with a selling price starting from RM 700,000.
# Each unit of superlink double storey house has extra land with a size of 175 sq ft.

# %%
from Property_Class import Highrise

# %%
new_property1 = Highrise("service apartment", 850, 3, 2, "Residensi Cemerlang, Kajang", 300000)
new_property1.describe_property()
new_property1.add_facilities({"infinity swimming pool","playground","sky garden"})
# Out:
# Each unit of service apartment with a size of 850 sq ft has 3 rooms and 2 bathrooms.
# It is located in Residensi Cemerlang, Kajang with a selling price starting from RM 300,000.
# This service apartment has many facilities such as sky garden, infinity swimming pool, playground.
